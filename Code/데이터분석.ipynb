# %%
import pandas as pd
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6164\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('c:\\study\\df4.csv',encoding='cp949')

# %%
df.describe()
# Out:
#                  일자         년              월              일              시  \
# count  7.082880e+05  708288.0  708288.000000  708288.000000  708288.000000
# mean   2.022072e+07    2022.0       7.000000      16.000000      11.500000
# std    3.938023e+02       0.0       3.937007       8.944278       6.922191
# min    2.022010e+07    2022.0       1.000000       1.000000       0.000000
# 25%    2.022056e+07    2022.0       5.500000       8.000000       5.750000
# 50%    2.022077e+07    2022.0       7.500000      16.000000      11.500000
# 75%    2.022092e+07    2022.0       9.000000      24.000000      17.250000
# max    2.022123e+07    2022.0      12.000000      31.000000      23.000000
#
#                  교통량        강수량(mm)        풍속(m/s)         적설(cm)  \
# count  607756.000000  708288.000000  708288.000000  708288.000000
# mean     1449.823350       0.280578       2.234039       0.194926
# std      1246.291952       1.965852       1.037435       0.598670
# ...

# %%
df['교통량']=df['교통량'].fillna(df['교통량'].median())

# %%
df.head(20)
# Out:
#        구        일자     년  월  일 요일             지점명  지점번호  방향              구분  \
# 0    종로구  20220101  2022  1  1  토       성산로(금화터널)  A-01  유입    봉원고가차도->독립문역
# 1    종로구  20220101  2022  1  1  토       성산로(금화터널)  A-01  유출    독립문역->봉원고가차도
# 2   서대문구  20220101  2022  1  1  토       사직로(사직터널)  A-02  유입       독립문역->사직단
# 3   서대문구  20220101  2022  1  1  토       사직로(사직터널)  A-02  유출       사직단->독립문역
# 4    종로구  20220101  2022  1  1  토     자하문로(자하문터널)  A-03  유입     석파정->청운초등학교
# 5    종로구  20220101  2022  1  1  토     자하문로(자하문터널)  A-03  유출     청운초등학교->석파정
# 6    성북구  20220101  2022  1  1  토      대사관로(삼청터널)  A-04  유입     삼청각->삼청공원입구
# 7    성북구  20220101  2022  1  1  토      대사관로(삼청터널)  A-04  유출     삼청공원입구->삼청각
# 8    종로구  20220101  2022  1  1  토        율곡로(안국역)  A-05  유입     안국역->안국동사거리
# 9    종로구  20220101  2022  1  1  토        율곡로(안국역)  A-05  유출     안국동사거리->안국역
# 10   종로구  20220101  2022  1  1  토   창경궁로(서울여자대학교)  A-06  유입  성균관대입구->원남동사거리
# ...

# %%
df.to_csv('C:/study/df4.csv',encoding='cp949',index=False)

# %%
df.describe()
# Out:
#                  일자         년              월              일              시  \
# count  7.082880e+05  708288.0  708288.000000  708288.000000  708288.000000
# mean   2.022072e+07    2022.0       7.000000      16.000000      11.500000
# std    3.938023e+02       0.0       3.937007       8.944278       6.922191
# min    2.022010e+07    2022.0       1.000000       1.000000       0.000000
# 25%    2.022056e+07    2022.0       5.500000       8.000000       5.750000
# 50%    2.022077e+07    2022.0       7.500000      16.000000      11.500000
# 75%    2.022092e+07    2022.0       9.000000      24.000000      17.250000
# max    2.022123e+07    2022.0      12.000000      31.000000      23.000000
#
#                  교통량        강수량(mm)        풍속(m/s)         적설(cm)  \
# count  708288.000000  708288.000000  708288.000000  708288.000000
# mean     1408.544869       0.280578       2.234039       0.194926
# std      1158.914158       1.965852       1.037435       0.598670
# ...

# %%
df2 = df.loc[(df['구']=='종로구')|
         (df['구']=='중구')|
         (df['구']=='성북구')|
         (df['구']=='동대문구')|
         (df['구']=='서대문구')]
df2.head()
# Out:
#       구        일자     년  월  일 요일          지점명  지점번호  방향            구분  시  \
# 0   종로구  20220101  2022  1  1  토    성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  0
# 1   종로구  20220101  2022  1  1  토    성산로(금화터널)  A-01  유출  독립문역->봉원고가차도  0
# 2  서대문구  20220101  2022  1  1  토    사직로(사직터널)  A-02  유입     독립문역->사직단  0
# 3  서대문구  20220101  2022  1  1  토    사직로(사직터널)  A-02  유출     사직단->독립문역  0
# 4   종로구  20220101  2022  1  1  토  자하문로(자하문터널)  A-03  유입   석파정->청운초등학교  0
#
#       교통량  강수량(mm)  풍속(m/s)  적설(cm)  지면온도(°C)
# 0  1159.0      0.0      1.9     0.0      -7.0
# 1  1159.0      0.0      1.9     0.0      -7.0
# 2   479.0      0.0      1.9     0.0      -7.0
# 3   780.0      0.0      1.9     0.0      -7.0
# 4   148.0      0.0      1.9     0.0      -7.0

# %%
df2.describe()
# Out:
#                  일자         년              월              일              시  \
# count  1.904640e+05  190464.0  190464.000000  190464.000000  190464.000000
# mean   2.022072e+07    2022.0       7.000000      16.000000      11.500000
# std    3.938030e+02       0.0       3.937014       8.944295       6.922205
# min    2.022010e+07    2022.0       1.000000       1.000000       0.000000
# 25%    2.022056e+07    2022.0       5.500000       8.000000       5.750000
# 50%    2.022077e+07    2022.0       7.500000      16.000000      11.500000
# 75%    2.022092e+07    2022.0       9.000000      24.000000      17.250000
# max    2.022123e+07    2022.0      12.000000      31.000000      23.000000
#
#                  교통량        강수량(mm)        풍속(m/s)         적설(cm)  \
# count  190464.000000  190464.000000  190464.000000  190464.000000
# mean     1012.113738       0.280578       2.234039       0.194926
# std       704.209809       1.965856       1.037437       0.598671
# ...

# %%
df2.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
sns.set_context('talk')
fig = plt.figure()
plt.rcParams['font.family'] = 'Malgun Gothic'

ax=sns.barplot(data=df2,x='구',y='교통량')
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6164\620189504.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
ax =sns.boxplot(data=df2,x='구',y='교통량')
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6164\2589642478.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# [Text(0, 0, '종로구'),
#  Text(1, 0, '서대문구'),
#  Text(2, 0, '성북구'),
#  Text(3, 0, '중구'),
#  Text(4, 0, '동대문구')]

# %%
df3= df2.drop(['구'],axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190464 entries, 0 to 708277
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   일자        190464 non-null  int64
#  1   년         190464 non-null  int64
#  2   월         190464 non-null  int64
#  3   일         190464 non-null  int64
#  4   요일        190464 non-null  object
#  5   지점명       190464 non-null  object
#  6   지점번호      190464 non-null  object
#  7   방향        190464 non-null  object
#  8   구분        190464 non-null  object
#  9   시         190464 non-null  int64
#  10  교통량       190464 non-null  float64
#  11  강수량(mm)   190464 non-null  float64
#  12  풍속(m/s)   190464 non-null  float64
#  13  적설(cm)    190464 non-null  float64
#  14  지면온도(°C)  190400 non-null  float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 23.2+ MB

# %%
df3['주중'] = 0
df3.loc[(df3['요일']=='토')|
        (df3['요일']=='일')|
        (df3['일자']==20220131)|
        (df3['일자']==20220815),'주중']=1
df3.head()
# Out:
#          일자     년  월  일 요일          지점명  지점번호  방향            구분  시     교통량  \
# 0  20220101  2022  1  1  토    성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  0  1159.0
# 1  20220101  2022  1  1  토    성산로(금화터널)  A-01  유출  독립문역->봉원고가차도  0  1159.0
# 2  20220101  2022  1  1  토    사직로(사직터널)  A-02  유입     독립문역->사직단  0   479.0
# 3  20220101  2022  1  1  토    사직로(사직터널)  A-02  유출     사직단->독립문역  0   780.0
# 4  20220101  2022  1  1  토  자하문로(자하문터널)  A-03  유입   석파정->청운초등학교  0   148.0
#
#    강수량(mm)  풍속(m/s)  적설(cm)  지면온도(°C)  주중
# 0      0.0      1.9     0.0      -7.0   1
# 1      0.0      1.9     0.0      -7.0   1
# 2      0.0      1.9     0.0      -7.0   1
# 3      0.0      1.9     0.0      -7.0   1
# 4      0.0      1.9     0.0      -7.0   1

# %%
df3=df3.drop(['요일','지점명','구분'],axis=1)
df3.head()
# Out:
#          일자     년  월  일  지점번호  방향  시     교통량  강수량(mm)  풍속(m/s)  적설(cm)  \
# 0  20220101  2022  1  1  A-01  유입  0  1159.0      0.0      1.9     0.0
# 1  20220101  2022  1  1  A-01  유출  0  1159.0      0.0      1.9     0.0
# 2  20220101  2022  1  1  A-02  유입  0   479.0      0.0      1.9     0.0
# 3  20220101  2022  1  1  A-02  유출  0   780.0      0.0      1.9     0.0
# 4  20220101  2022  1  1  A-03  유입  0   148.0      0.0      1.9     0.0
#
#    지면온도(°C)  주중
# 0      -7.0   1
# 1      -7.0   1
# 2      -7.0   1
# 3      -7.0   1
# 4      -7.0   1

# %%
df3.loc[df['방향']=='유입','방향'] =0
df3.loc[df['방향']=='유출','방향'] =1
df3.head()
# Out:
#          일자     년  월  일  지점번호 방향  시     교통량  강수량(mm)  풍속(m/s)  적설(cm)  \
# 0  20220101  2022  1  1  A-01  0  0  1159.0      0.0      1.9     0.0
# 1  20220101  2022  1  1  A-01  1  0  1159.0      0.0      1.9     0.0
# 2  20220101  2022  1  1  A-02  0  0   479.0      0.0      1.9     0.0
# 3  20220101  2022  1  1  A-02  1  0   780.0      0.0      1.9     0.0
# 4  20220101  2022  1  1  A-03  0  0   148.0      0.0      1.9     0.0
#
#    지면온도(°C)  주중
# 0      -7.0   1
# 1      -7.0   1
# 2      -7.0   1
# 3      -7.0   1
# 4      -7.0   1

# %%
df3=df3.drop(['지점번호'],axis=1)
df3.head()
# Out:
#          일자     년  월  일 방향  시     교통량  강수량(mm)  풍속(m/s)  적설(cm)  지면온도(°C)  주중
# 0  20220101  2022  1  1  0  0  1159.0      0.0      1.9     0.0      -7.0   1
# 1  20220101  2022  1  1  1  0  1159.0      0.0      1.9     0.0      -7.0   1
# 2  20220101  2022  1  1  0  0   479.0      0.0      1.9     0.0      -7.0   1
# 3  20220101  2022  1  1  1  0   780.0      0.0      1.9     0.0      -7.0   1
# 4  20220101  2022  1  1  0  0   148.0      0.0      1.9     0.0      -7.0   1

# %%
df3=df3.drop(['년'],axis=1)
df3.head()
# Out:
#          일자  월  일 방향  시     교통량  강수량(mm)  풍속(m/s)  적설(cm)  지면온도(°C)  주중
# 0  20220101  1  1  0  0  1159.0      0.0      1.9     0.0      -7.0   1
# 1  20220101  1  1  1  0  1159.0      0.0      1.9     0.0      -7.0   1
# 2  20220101  1  1  0  0   479.0      0.0      1.9     0.0      -7.0   1
# 3  20220101  1  1  1  0   780.0      0.0      1.9     0.0      -7.0   1
# 4  20220101  1  1  0  0   148.0      0.0      1.9     0.0      -7.0   1

# %%
df3=df3.drop(['일자'],axis=1)
df3.head()
# Out:
#    월  일 방향  시     교통량  강수량(mm)  풍속(m/s)  적설(cm)  지면온도(°C)  주중
# 0  1  1  0  0  1159.0      0.0      1.9     0.0      -7.0   1
# 1  1  1  1  0  1159.0      0.0      1.9     0.0      -7.0   1
# 2  1  1  0  0   479.0      0.0      1.9     0.0      -7.0   1
# 3  1  1  1  0   780.0      0.0      1.9     0.0      -7.0   1
# 4  1  1  0  0   148.0      0.0      1.9     0.0      -7.0   1

# %%
sns.set_context('notebook')

fig=plt.figure(figsize=(10,10))
ax=sns.heatmap(df3.corr(),annot=True, cmap='viridis')
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
