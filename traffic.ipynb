# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


file='동대문구.xlsx'
df = pd.read_excel(file)
print(df)

sns.relplot(x="강수량(mm)",y="보정된 교통량",
            kind="line",hue="시", col= "구분", data=df)
# Out:
#         구        일자     년  월   일  지점명             구분   시   교통량  강수량(mm)  \
# 0    동대문구  20220101  2022  1   1    1  망우로 -> 삼육서울병원  오후   836        0
# 1    동대문구  20220101  2022  1   1    1  망우로 -> 삼육서울병원  오전   224        0
# 2    동대문구  20220102  2022  1   2    1  망우로 -> 삼육서울병원  오후   777        0
# 3    동대문구  20220102  2022  1   2    1  망우로 -> 삼육서울병원  오전   189        0
# 4    동대문구  20220103  2022  1   3    1  망우로 -> 삼육서울병원  오후  1373        0
# ..    ...       ...   ... ..  ..  ...            ...  ..   ...      ...
# 367  동대문구  20220729  2022  7  29    3  이문로 -> 서울성심병원  오전  4847        0
# 368  동대문구  20220730  2022  7  30    3  이문로 -> 서울성심병원  오후  5543        0
# 369  동대문구  20220730  2022  7  30    3  이문로 -> 서울성심병원  오전  2341        0
# 370  동대문구  20220731  2022  7  31    3  이문로 -> 서울성심병원  오후  5349        1
# 371  동대문구  20220731  2022  7  31    3  이문로 -> 서울성심병원  오전  1593        0
#
#           함수  보정된 교통량
# 0       83.6     83.6
# 1     2240.0   2240.0
# 2       77.7     77.7
# ...

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


file='서대문구.xlsx'
df = pd.read_excel(file)
print(df)

sns.relplot(x="강수량(mm)",y="보정된 교통량",
            kind="line",hue="시", col= "구분", data=df)
# Out:
#         구        일자     년  월   일                      구분   시   교통량  강수량(mm)  \
# 0    서대문구  20220101  2022  1   1             통일로 -> 세란병원  오후  1728        0
# 1    서대문구  20220101  2022  1   1             통일로 -> 세란병원  오전   886        0
# 2    서대문구  20220102  2022  1   2             통일로 -> 세란병원  오후  1710        0
# 3    서대문구  20220102  2022  1   2             통일로 -> 세란병원  오전   665        0
# 4    서대문구  20220103  2022  1   3             통일로 -> 세란병원  오후  1652        0
# ..    ...       ...   ... ..  ..                     ...  ..   ...      ...
# 243  서대문구  20220729  2022  7  29  모래내로 -> 의료법인동신의료재단동신병원  오전  4303        0
# 244  서대문구  20220730  2022  7  30  모래내로 -> 의료법인동신의료재단동신병원  오후  4321        0
# 245  서대문구  20220730  2022  7  30  모래내로 -> 의료법인동신의료재단동신병원  오전  3656        1
# 246  서대문구  20220731  2022  7  31  모래내로 -> 의료법인동신의료재단동신병원  오후  3942        1
# 247  서대문구  20220731  2022  7  31  모래내로 -> 의료법인동신의료재단동신병원  오전  2537        0
#
#           함수  보정된 교통량
# 0      172.8    172.8
# ...

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


file='종로구.xlsx'
df = pd.read_excel(file)
print(df)

sns.relplot(x="강수량(mm)",y="보정된 교통량",
            kind="line",hue="시", col= "구분", data=df)
# Out:
#        구        일자     년  월   일               구분   시   교통량  강수량(mm)       함수  \
# 0    종로구  20220101  2022  1   1   율곡로 -> 서울대학교병원  오후   997        0     99.7
# 1    종로구  20220101  2022  1   1   율곡로 -> 서울대학교병원  오전   307        0   3070.0
# 2    종로구  20220102  2022  1   2   율곡로 -> 서울대학교병원  오후  1047        0    104.7
# 3    종로구  20220102  2022  1   2   율곡로 -> 서울대학교병원  오전   283        0   2830.0
# 4    종로구  20220103  2022  1   3   율곡로 -> 서울대학교병원  오후  1270        0    127.0
# ..   ...       ...   ... ..  ..              ...  ..   ...      ...      ...
# 367  종로구  20220729  2022  7  29  새문안로 -> 서울적십자병원  오전  6789        0    678.9
# 368  종로구  20220730  2022  7  30  새문안로 -> 서울적십자병원  오후  5506        0   5506.0
# 369  종로구  20220730  2022  7  30  새문안로 -> 서울적십자병원  오전  6112        1  12224.0
# 370  종로구  20220731  2022  7  31  새문안로 -> 서울적십자병원  오후  5456        1    545.6
# 371  종로구  20220731  2022  7  31  새문안로 -> 서울적십자병원  오전  3575        0    357.5
#
#      보정된 교통량
# 0       99.7
# 1     3070.0
# ...

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


file='중구.xlsx'
df = pd.read_excel(file)
print(df)

sns.relplot(x="강수량(mm)",y="보정된 교통량",
            kind="line",hue="시", col= "구분", data=df)
# Out:
#       구        일자     년  월   일               구분   시   교통량  강수량(mm)  \
# 0    중구  20220101  2022  1   1  장춘단로 -> 국립중앙의료원  오후  5063        0
# 1    중구  20220101  2022  1   1  장춘단로 -> 국립중앙의료원  오전  2086        0
# 2    중구  20220102  2022  1   2  장춘단로 -> 국립중앙의료원  오후  5488        0
# 3    중구  20220102  2022  1   2  장춘단로 -> 국립중앙의료원  오전  1862        0
# 4    중구  20220103  2022  1   3  장춘단로 -> 국립중앙의료원  오후  6024        0
# ..   ..       ...   ... ..  ..              ...  ..   ...      ...
# 243  중구  20220729  2022  7  29   동호로 -> 국립중앙의료원  오전  1159        0
# 244  중구  20220730  2022  7  30   동호로 -> 국립중앙의료원  오후  1159        0
# 245  중구  20220730  2022  7  30   동호로 -> 국립중앙의료원  오전  1159        1
# 246  중구  20220731  2022  7  31   동호로 -> 국립중앙의료원  오후  1159        1
# 247  중구  20220731  2022  7  31   동호로 -> 국립중앙의료원  오전  1159        0
#
#                함수       보정된 교통량
# 0     1012.600000   1012.600000
# 1     4172.000000   4172.000000
# 2     1097.600000   1097.600000
# ...

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


file='종로구2.xlsx'
df = pd.read_excel(file)
print(df)

sns.relplot(x="강수량(mm)",y="보정된 교통량",
            kind="line",hue="시", col= "구분", data=df)
# Out:
#          구        일자     년   월   일             구분   시   교통량  강수량(mm)  \
# 0     종로구2  20220101  2022   1   1  종로 -> 국립중앙의료원  오후   988        0
# 1     종로구2  20220101  2022   1   1  종로 -> 국립중앙의료원  오전   407        0
# 2     종로구2  20220102  2022   1   2  종로 -> 국립중앙의료원  오후   989        0
# 3     종로구2  20220102  2022   1   2  종로 -> 국립중앙의료원  오전   335        0
# 4     종로구2  20220103  2022   1   3  종로 -> 국립중앙의료원  오후  1223        0
# ..     ...       ...   ...  ..  ..            ...  ..   ...      ...
# 987  종로구22  20221229  2022  12  29  왕산로 -> 서울성심병원  오전  4207        1
# 988  종로구22  20221230  2022  12  30  왕산로 -> 서울성심병원  오후  5816        1
# 989  종로구22  20221230  2022  12  30  왕산로 -> 서울성심병원  오전  4044        1
# 990  종로구22  20221231  2022  12  31  왕산로 -> 서울성심병원  오후  4637        0
# 991  종로구22  20221231  2022  12  31  왕산로 -> 서울성심병원  오전  2626        0
#
#                함수       보정된 교통량
# 0       98.800000     98.800000
# 1     4070.000000   4070.000000
# 2       98.900000     98.900000
# ...
